# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
movie_line = "cornell movie-dialogs corpus/movie_lines.txt"
movie_convo = "cornell movie-dialogs corpus/movie_conversations.txt"

m_lines = open(movie_line , encoding='utf-8',errors='ignore').read().split('\n')
c_lines = open(movie_convo , encoding='utf-8',errors='ignore').read().split('\n')

convo_line = []
for lines in c_lines:
    _lines = lines.split(" +++$+++ ")[-1][1:-1].replace("'","").replace(" ","")
    convo_line.append(_lines.split(","))

id_line = {}
for lines in m_lines:
    _lines = lines.split(" +++$+++ ")
    if len(_lines) == 5:
        id_line[_lines[0]] = _lines[4]

questions = []
answers = []

for line in convo_line:
    for i in range(len(line) -1):
        questions.append(id_line[line[i]])
        answers.append(id_line[line[i+1]])

# %%
def preprocess_sentence(text):
    text = text.lower()
    
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"  ","",text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text)
    
    text = re.sub(r"([?.!,¿])", r" \1 ", text)
    text = re.sub(r'[" "]+', " ", text)
    text = re.sub(r"[^a-zA-Z?.!,¿]+", " ", text)

    text = text.strip()
    text = '<start> ' + text + ' <end>'
    return text

# %%
preprocess_sentence(questions[0])
# Out:
# '<start> can we make this quickroxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quadagain <end>'

# %%
clean_questions = []
clean_answers = []

for q in questions:
    clean_questions.append(preprocess_sentence(q))
for a in answers:
    clean_answers.append(preprocess_sentence(a))

# %%
max_length = 20
min_length = 2
short_questions_temp = []
short_answers_temp = []

i = 0
for question in clean_questions:
    if len(question.split()) >= min_length and len(question.split()) <= max_length:
        short_questions_temp.append(question)
        short_answers_temp.append(clean_answers[i])
    i += 1

# Filter out the answers that are too short/long
shorted_q = []
shorted_a = []

i = 0
for answer in short_answers_temp:
    if len(answer.split()) >= min_length and len(answer.split()) <= max_length:
        shorted_a.append(answer)
        shorted_q.append(short_questions_temp[i])
    i += 1

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

    return tensor, lang_tokenizer

# %%
def load_dataset(inp_lang, targ_lang):
  # creating cleaned input, output pairs
    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(shorted_q, shorted_a)

# %%
input_tensor.shape
# Out:
# (159650, 20)

# %%
target_tensor.shape
# Out:
# (159650, 20)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 127720 127720 31930 31930

# %%
def convert(lang, tensor):
    for t in tensor:
        if t!=0:
            print("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 1902 ----> jamie
# 12517 ----> kurth
# 5078 ----> jonathan
# 5360 ----> edmunds
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 28 ----> my
# 170 ----> god
# 700 ----> nick
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 20]), TensorShape([64, 20]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return output, state

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 20, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
        query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(query_with_time_axis) + self.W2(values)))

    # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 20, 1)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
        context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
        output, state = self.gru(x)

    # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
        x = self.fc(output)

        return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 50959)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './nmt_with_attention_movie/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

          
            loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

  
    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 61

for epoch in range(EPOCHS):
  
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
    if epoch%10 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.4599
# Epoch 1 Batch 100 Loss 2.6495
# Epoch 1 Batch 200 Loss 2.3718
# Epoch 1 Batch 300 Loss 2.0927
# Epoch 1 Batch 400 Loss 2.1782
# Epoch 1 Batch 500 Loss 2.4712
# Epoch 1 Batch 600 Loss 2.2472
# Epoch 1 Batch 700 Loss 2.0815
# Epoch 1 Batch 800 Loss 2.1333
# Epoch 1 Batch 900 Loss 2.1804
# Epoch 1 Batch 1000 Loss 2.0736
# Epoch 1 Batch 1100 Loss 1.6815
# Epoch 1 Batch 1200 Loss 2.2273
# Epoch 1 Batch 1300 Loss 2.2084
# Epoch 1 Batch 1400 Loss 2.2673
# Epoch 1 Batch 1500 Loss 2.1853
# Epoch 1 Batch 1600 Loss 1.7654
# Epoch 1 Batch 1700 Loss 2.2884
# Epoch 1 Batch 1800 Loss 1.7410
# Epoch 1 Batch 1900 Loss 1.9838
# Epoch 1 Loss 2.2219
# Time taken for 1 epoch 619.507169008255 sec
#
# Epoch 2 Batch 0 Loss 2.0046
# Epoch 2 Batch 100 Loss 1.7256
# Epoch 2 Batch 200 Loss 1.8624
# Epoch 2 Batch 300 Loss 1.7494
# Epoch 2 Batch 400 Loss 2.0797
# Epoch 2 Batch 500 Loss 1.9574
# Epoch 2 Batch 600 Loss 2.1162
# Epoch 2 Batch 700 Loss 1.9051
# Epoch 2 Batch 800 Loss 1.8920
# Epoch 2 Batch 900 Loss 2.0497
# Epoch 2 Batch 1000 Loss 2.3649
# Epoch 2 Batch 1100 Loss 2.2942
# Epoch 2 Batch 1200 Loss 2.0211
# Epoch 2 Batch 1300 Loss 1.7659
# Epoch 2 Batch 1400 Loss 1.8827
# Epoch 2 Batch 1500 Loss 2.1243
# Epoch 2 Batch 1600 Loss 2.0179
# Epoch 2 Batch 1700 Loss 1.7862
# Epoch 2 Batch 1800 Loss 1.9104
# Epoch 2 Batch 1900 Loss 1.8319
# Epoch 2 Loss 1.9637
# Time taken for 1 epoch 618.1317746639252 sec
#
# Epoch 3 Batch 0 Loss 2.0574
# Epoch 3 Batch 100 Loss 1.9196
# Epoch 3 Batch 200 Loss 1.8597
# Epoch 3 Batch 300 Loss 1.7232
# Epoch 3 Batch 400 Loss 1.9380
# Epoch 3 Batch 500 Loss 1.8759
# Epoch 3 Batch 600 Loss 1.9128
# Epoch 3 Batch 700 Loss 1.9079
# Epoch 3 Batch 800 Loss 1.7323
# Epoch 3 Batch 900 Loss 1.6365
# Epoch 3 Batch 1000 Loss 1.9752
# Epoch 3 Batch 1100 Loss 1.8684
# Epoch 3 Batch 1200 Loss 1.6574
# Epoch 3 Batch 1300 Loss 1.6428
# Epoch 3 Batch 1400 Loss 2.0388
# Epoch 3 Batch 1500 Loss 2.3095
# Epoch 3 Batch 1600 Loss 1.9859
# Epoch 3 Batch 1700 Loss 1.8671
# Epoch 3 Batch 1800 Loss 2.0645
# Epoch 3 Batch 1900 Loss 1.6320
# Epoch 3 Loss 1.8536
# Time taken for 1 epoch 617.6476941108704 sec
#
# Epoch 4 Batch 0 Loss 1.8986
# Epoch 4 Batch 100 Loss 1.7587
# Epoch 4 Batch 200 Loss 1.7608
# Epoch 4 Batch 300 Loss 1.8060
# Epoch 4 Batch 400 Loss 1.7957
# Epoch 4 Batch 500 Loss 1.7510
# Epoch 4 Batch 600 Loss 1.7098
# Epoch 4 Batch 700 Loss 1.9233
# Epoch 4 Batch 800 Loss 1.9436
# Epoch 4 Batch 900 Loss 1.8304
# Epoch 4 Batch 1000 Loss 2.3328
# Epoch 4 Batch 1100 Loss 1.6636
# Epoch 4 Batch 1200 Loss 1.8298
# Epoch 4 Batch 1300 Loss 1.8917
# Epoch 4 Batch 1400 Loss 1.7693
# Epoch 4 Batch 1500 Loss 1.6554
# Epoch 4 Batch 1600 Loss 1.7480
# Epoch 4 Batch 1700 Loss 1.8456
# Epoch 4 Batch 1800 Loss 1.7854
# Epoch 4 Batch 1900 Loss 1.6942
# Epoch 4 Loss 1.7701
# Time taken for 1 epoch 616.976135969162 sec
#
# Epoch 5 Batch 0 Loss 1.5140
# Epoch 5 Batch 100 Loss 1.6252
# Epoch 5 Batch 200 Loss 1.8617
# Epoch 5 Batch 300 Loss 1.6607
# Epoch 5 Batch 400 Loss 1.7364
# Epoch 5 Batch 500 Loss 1.9314
# Epoch 5 Batch 600 Loss 1.8223
# Epoch 5 Batch 700 Loss 1.6095
# Epoch 5 Batch 800 Loss 1.9760
# Epoch 5 Batch 900 Loss 2.0017
# Epoch 5 Batch 1000 Loss 1.7298
# Epoch 5 Batch 1100 Loss 1.7893
# Epoch 5 Batch 1200 Loss 1.8623
# Epoch 5 Batch 1300 Loss 1.6471
# Epoch 5 Batch 1400 Loss 1.9138
# Epoch 5 Batch 1500 Loss 1.3923
# Epoch 5 Batch 1600 Loss 1.8861
# Epoch 5 Batch 1700 Loss 1.7716
# Epoch 5 Batch 1800 Loss 1.6129
# Epoch 5 Batch 1900 Loss 1.6880
# Epoch 5 Loss 1.6917
# Time taken for 1 epoch 617.3425397872925 sec
#
# Epoch 6 Batch 0 Loss 1.5839
# Epoch 6 Batch 100 Loss 2.0986
# Epoch 6 Batch 200 Loss 1.4444
# Epoch 6 Batch 300 Loss 1.5743
# Epoch 6 Batch 400 Loss 1.6441
# Epoch 6 Batch 500 Loss 1.3927
# Epoch 6 Batch 600 Loss 1.5691
# Epoch 6 Batch 700 Loss 1.5196
# Epoch 6 Batch 800 Loss 1.5406
# Epoch 6 Batch 900 Loss 1.5315
# Epoch 6 Batch 1000 Loss 1.6102
# Epoch 6 Batch 1100 Loss 1.2887
# Epoch 6 Batch 1200 Loss 1.9283
# Epoch 6 Batch 1300 Loss 1.6833
# Epoch 6 Batch 1400 Loss 1.5780
# Epoch 6 Batch 1500 Loss 1.5853
# Epoch 6 Batch 1600 Loss 1.5870
# Epoch 6 Batch 1700 Loss 1.3609
# Epoch 6 Batch 1800 Loss 1.3989
# Epoch 6 Batch 1900 Loss 1.5858
# Epoch 6 Loss 1.6111
# Time taken for 1 epoch 617.0063138008118 sec
#
# Epoch 7 Batch 0 Loss 1.7302
# Epoch 7 Batch 100 Loss 1.4877
# Epoch 7 Batch 200 Loss 1.3306
# Epoch 7 Batch 300 Loss 1.5026
# Epoch 7 Batch 400 Loss 1.4059
# Epoch 7 Batch 500 Loss 1.4918
# Epoch 7 Batch 600 Loss 1.3734
# Epoch 7 Batch 700 Loss 1.5016
# Epoch 7 Batch 800 Loss 1.4892
# Epoch 7 Batch 900 Loss 1.5076
# Epoch 7 Batch 1000 Loss 1.7885
# Epoch 7 Batch 1100 Loss 1.4617
# Epoch 7 Batch 1200 Loss 1.5890
# Epoch 7 Batch 1300 Loss 1.5969
# Epoch 7 Batch 1400 Loss 1.4495
# Epoch 7 Batch 1500 Loss 1.4817
# Epoch 7 Batch 1600 Loss 1.7305
# Epoch 7 Batch 1700 Loss 1.5339
# Epoch 7 Batch 1800 Loss 1.5608
# Epoch 7 Batch 1900 Loss 1.4616
# Epoch 7 Loss 1.5233
# Time taken for 1 epoch 617.4312605857849 sec
#
# Epoch 8 Batch 0 Loss 1.4692
# Epoch 8 Batch 100 Loss 1.3912
# Epoch 8 Batch 200 Loss 1.4937
# Epoch 8 Batch 300 Loss 1.5606
# Epoch 8 Batch 400 Loss 1.1697
# Epoch 8 Batch 500 Loss 1.2261
# Epoch 8 Batch 600 Loss 1.3295
# Epoch 8 Batch 700 Loss 1.3843
# Epoch 8 Batch 800 Loss 1.4834
# Epoch 8 Batch 900 Loss 1.3419
# Epoch 8 Batch 1000 Loss 1.2550
# Epoch 8 Batch 1100 Loss 1.3122
# Epoch 8 Batch 1200 Loss 1.3348
# Epoch 8 Batch 1300 Loss 1.4193
# Epoch 8 Batch 1400 Loss 1.1525
# Epoch 8 Batch 1500 Loss 1.4083
# Epoch 8 Batch 1600 Loss 1.3371
# Epoch 8 Batch 1700 Loss 1.4287
# Epoch 8 Batch 1800 Loss 1.2994
# Epoch 8 Batch 1900 Loss 1.4743
# Epoch 8 Loss 1.4304
# Time taken for 1 epoch 616.8674411773682 sec
#
# Epoch 9 Batch 0 Loss 1.2627
# Epoch 9 Batch 100 Loss 1.4517
# Epoch 9 Batch 200 Loss 1.2731
# Epoch 9 Batch 300 Loss 1.3879
# Epoch 9 Batch 400 Loss 1.3325
# Epoch 9 Batch 500 Loss 1.3446
# Epoch 9 Batch 600 Loss 1.2764
# Epoch 9 Batch 700 Loss 1.3212
# Epoch 9 Batch 800 Loss 1.4000
# Epoch 9 Batch 900 Loss 1.4380
# Epoch 9 Batch 1000 Loss 1.3662
# Epoch 9 Batch 1100 Loss 1.2976
# Epoch 9 Batch 1200 Loss 1.4736
# Epoch 9 Batch 1300 Loss 1.1519
# Epoch 9 Batch 1400 Loss 1.2333
# Epoch 9 Batch 1500 Loss 1.3058
# Epoch 9 Batch 1600 Loss 1.2948
# Epoch 9 Batch 1700 Loss 1.3248
# Epoch 9 Batch 1800 Loss 1.4680
# Epoch 9 Batch 1900 Loss 1.4264
# Epoch 9 Loss 1.3374
# Time taken for 1 epoch 615.9069640636444 sec
#
# Epoch 10 Batch 0 Loss 1.1518
# Epoch 10 Batch 100 Loss 1.1744
# Epoch 10 Batch 200 Loss 1.1026
# Epoch 10 Batch 300 Loss 1.1362
# Epoch 10 Batch 400 Loss 1.2358
# Epoch 10 Batch 500 Loss 1.0928
# Epoch 10 Batch 600 Loss 1.0081
# Epoch 10 Batch 700 Loss 1.1974
# Epoch 10 Batch 800 Loss 1.2248
# Epoch 10 Batch 900 Loss 1.1200
# Epoch 10 Batch 1000 Loss 1.3237
# Epoch 10 Batch 1100 Loss 1.4337
# Epoch 10 Batch 1200 Loss 1.2876
# Epoch 10 Batch 1300 Loss 1.3608
# Epoch 10 Batch 1400 Loss 1.2650
# Epoch 10 Batch 1500 Loss 1.2763
# Epoch 10 Batch 1600 Loss 1.2864
# Epoch 10 Batch 1700 Loss 1.2457
# Epoch 10 Batch 1800 Loss 1.4475
# Epoch 10 Batch 1900 Loss 0.9859
# Epoch 10 Loss 1.2456
# Time taken for 1 epoch 616.756831407547 sec
#
# Epoch 11 Batch 0 Loss 1.0220
# Epoch 11 Batch 100 Loss 1.1534
# Epoch 11 Batch 200 Loss 1.3203
# Epoch 11 Batch 300 Loss 1.1428
# Epoch 11 Batch 400 Loss 1.3732
# Epoch 11 Batch 500 Loss 1.2360
# Epoch 11 Batch 600 Loss 1.4707
# Epoch 11 Batch 700 Loss 1.1112
# Epoch 11 Batch 800 Loss 1.0985
# Epoch 11 Batch 900 Loss 0.9961
# Epoch 11 Batch 1000 Loss 1.1116
# Epoch 11 Batch 1100 Loss 1.2573
# Epoch 11 Batch 1200 Loss 1.2452
# Epoch 11 Batch 1300 Loss 0.9682
# Epoch 11 Batch 1400 Loss 1.1451
# Epoch 11 Batch 1500 Loss 1.1407
# Epoch 11 Batch 1600 Loss 1.2089
# Epoch 11 Batch 1700 Loss 1.1892
# Epoch 11 Batch 1800 Loss 1.3778
# Epoch 11 Batch 1900 Loss 1.2881
# Epoch 11 Loss 1.1584
# Time taken for 1 epoch 618.4665517807007 sec
#
# Epoch 12 Batch 0 Loss 1.0610
# Epoch 12 Batch 100 Loss 1.0790
# Epoch 12 Batch 200 Loss 0.9667
# Epoch 12 Batch 300 Loss 1.1415
# Epoch 12 Batch 400 Loss 1.0705
# Epoch 12 Batch 500 Loss 0.9107
# Epoch 12 Batch 600 Loss 1.1006
# Epoch 12 Batch 700 Loss 1.1164
# Epoch 12 Batch 800 Loss 1.2080
# Epoch 12 Batch 900 Loss 1.0350
# Epoch 12 Batch 1000 Loss 1.0040
# Epoch 12 Batch 1100 Loss 1.1431
# Epoch 12 Batch 1200 Loss 0.8986
# Epoch 12 Batch 1300 Loss 1.0085
# Epoch 12 Batch 1400 Loss 1.2476
# Epoch 12 Batch 1500 Loss 1.0180
# Epoch 12 Batch 1600 Loss 1.1208
# Epoch 12 Batch 1700 Loss 1.2103
# Epoch 12 Batch 1800 Loss 1.0769
# Epoch 12 Batch 1900 Loss 1.1622
# Epoch 12 Loss 1.0772
# Time taken for 1 epoch 617.0294051170349 sec
#
# Epoch 13 Batch 0 Loss 0.8360
# Epoch 13 Batch 100 Loss 0.7918
# Epoch 13 Batch 200 Loss 1.0034
# Epoch 13 Batch 300 Loss 1.1884
# Epoch 13 Batch 400 Loss 1.0150
# Epoch 13 Batch 500 Loss 0.9828
# Epoch 13 Batch 600 Loss 1.1105
# Epoch 13 Batch 700 Loss 0.9494
# Epoch 13 Batch 800 Loss 1.0155
# Epoch 13 Batch 900 Loss 0.9488
# Epoch 13 Batch 1000 Loss 0.9140
# Epoch 13 Batch 1100 Loss 0.9869
# Epoch 13 Batch 1200 Loss 1.1031
# Epoch 13 Batch 1300 Loss 1.0958
# Epoch 13 Batch 1400 Loss 1.0469
# Epoch 13 Batch 1500 Loss 1.0812
# Epoch 13 Batch 1600 Loss 0.9983
# Epoch 13 Batch 1700 Loss 0.9860
# Epoch 13 Batch 1800 Loss 1.0148
# Epoch 13 Batch 1900 Loss 1.1546
# Epoch 13 Loss 1.0016
# Time taken for 1 epoch 617.4965665340424 sec
#
# Epoch 14 Batch 0 Loss 1.0265
# Epoch 14 Batch 100 Loss 0.8882
# Epoch 14 Batch 200 Loss 0.8830
# Epoch 14 Batch 300 Loss 0.8035
# Epoch 14 Batch 400 Loss 0.8302
# Epoch 14 Batch 500 Loss 0.8704
# Epoch 14 Batch 600 Loss 0.9871
# Epoch 14 Batch 700 Loss 0.9409
# Epoch 14 Batch 800 Loss 0.9995
# Epoch 14 Batch 900 Loss 0.9523
# Epoch 14 Batch 1000 Loss 1.0269
# Epoch 14 Batch 1100 Loss 0.9621
# Epoch 14 Batch 1200 Loss 1.0703
# Epoch 14 Batch 1300 Loss 0.8281
# Epoch 14 Batch 1400 Loss 1.0025
# Epoch 14 Batch 1500 Loss 1.0010
# Epoch 14 Batch 1600 Loss 0.8253
# Epoch 14 Batch 1700 Loss 1.0683
# Epoch 14 Batch 1800 Loss 1.0016
# Epoch 14 Batch 1900 Loss 1.0190
# Epoch 14 Loss 0.9325
# Time taken for 1 epoch 616.7366714477539 sec
#
# Epoch 15 Batch 0 Loss 0.8310
# Epoch 15 Batch 100 Loss 0.7919
# Epoch 15 Batch 200 Loss 0.8926
# Epoch 15 Batch 300 Loss 0.9551
# Epoch 15 Batch 400 Loss 0.9257
# Epoch 15 Batch 500 Loss 0.7951
# Epoch 15 Batch 600 Loss 0.9722
# Epoch 15 Batch 700 Loss 0.7827
# Epoch 15 Batch 800 Loss 0.8943
# Epoch 15 Batch 900 Loss 0.7992
# Epoch 15 Batch 1000 Loss 0.8873
# Epoch 15 Batch 1100 Loss 0.8393
# Epoch 15 Batch 1200 Loss 0.9193
# Epoch 15 Batch 1300 Loss 0.8635
# Epoch 15 Batch 1400 Loss 0.7091
# Epoch 15 Batch 1500 Loss 0.8211
# Epoch 15 Batch 1600 Loss 0.6907
# Epoch 15 Batch 1700 Loss 0.8581
# Epoch 15 Batch 1800 Loss 0.9384
# Epoch 15 Batch 1900 Loss 0.9372
# Epoch 15 Loss 0.8676
# Time taken for 1 epoch 611.8736441135406 sec
#
# Epoch 16 Batch 0 Loss 0.6946
# Epoch 16 Batch 100 Loss 0.8151
# Epoch 16 Batch 200 Loss 0.7322
# Epoch 16 Batch 300 Loss 0.8613
# Epoch 16 Batch 400 Loss 0.7217
# Epoch 16 Batch 500 Loss 0.7850
# Epoch 16 Batch 600 Loss 0.6962
# Epoch 16 Batch 700 Loss 0.7993
# Epoch 16 Batch 800 Loss 0.8202
# Epoch 16 Batch 900 Loss 0.7204
# Epoch 16 Batch 1000 Loss 0.6973
# Epoch 16 Batch 1100 Loss 0.8438
# Epoch 16 Batch 1200 Loss 0.9337
# Epoch 16 Batch 1300 Loss 0.7931
# Epoch 16 Batch 1400 Loss 0.7867
# Epoch 16 Batch 1500 Loss 0.7604
# Epoch 16 Batch 1600 Loss 0.7732
# Epoch 16 Batch 1700 Loss 0.7489
# Epoch 16 Batch 1800 Loss 0.8659
# Epoch 16 Batch 1900 Loss 0.8729
# Epoch 16 Loss 0.8073
# Time taken for 1 epoch 612.2602491378784 sec
#
# Epoch 17 Batch 0 Loss 0.7927
# Epoch 17 Batch 100 Loss 0.5710
# Epoch 17 Batch 200 Loss 0.6652
# Epoch 17 Batch 300 Loss 0.7370
# Epoch 17 Batch 400 Loss 0.7594
# Epoch 17 Batch 500 Loss 0.7089
# Epoch 17 Batch 600 Loss 0.6647
# Epoch 17 Batch 700 Loss 0.5622
# Epoch 17 Batch 800 Loss 0.7355
# Epoch 17 Batch 900 Loss 0.7471
# Epoch 17 Batch 1000 Loss 0.7827
# Epoch 17 Batch 1100 Loss 0.7492
# Epoch 17 Batch 1200 Loss 0.7172
# Epoch 17 Batch 1300 Loss 0.7170
# Epoch 17 Batch 1400 Loss 0.7736
# Epoch 17 Batch 1500 Loss 0.8921
# Epoch 17 Batch 1600 Loss 0.7345
# Epoch 17 Batch 1700 Loss 0.7973
# Epoch 17 Batch 1800 Loss 0.6586
# Epoch 17 Batch 1900 Loss 0.6395
# Epoch 17 Loss 0.7508
# Time taken for 1 epoch 614.9639790058136 sec
#
# Epoch 18 Batch 0 Loss 0.6819
# Epoch 18 Batch 100 Loss 0.6322
# Epoch 18 Batch 200 Loss 0.6545
# Epoch 18 Batch 300 Loss 0.7980
# Epoch 18 Batch 400 Loss 0.7475
# Epoch 18 Batch 500 Loss 0.6941
# Epoch 18 Batch 600 Loss 0.6859
# Epoch 18 Batch 700 Loss 0.6674
# Epoch 18 Batch 800 Loss 0.6224
# Epoch 18 Batch 900 Loss 0.6751
# Epoch 18 Batch 1000 Loss 0.7146
# Epoch 18 Batch 1100 Loss 0.5758
# Epoch 18 Batch 1200 Loss 0.7334
# Epoch 18 Batch 1300 Loss 0.6366
# Epoch 18 Batch 1400 Loss 0.7942
# Epoch 18 Batch 1500 Loss 0.6803
# Epoch 18 Batch 1600 Loss 0.7219
# Epoch 18 Batch 1700 Loss 0.7282
# Epoch 18 Batch 1800 Loss 0.7724
# Epoch 18 Batch 1900 Loss 0.5727
# Epoch 18 Loss 0.6981
# Time taken for 1 epoch 615.7376894950867 sec
#
# Epoch 19 Batch 0 Loss 0.5931
# Epoch 19 Batch 100 Loss 0.6068
# Epoch 19 Batch 200 Loss 0.4271
# Epoch 19 Batch 300 Loss 0.6244
# Epoch 19 Batch 400 Loss 0.7290
# Epoch 19 Batch 500 Loss 0.6759
# Epoch 19 Batch 600 Loss 0.6100
# Epoch 19 Batch 700 Loss 0.5551
# Epoch 19 Batch 800 Loss 0.7051
# Epoch 19 Batch 900 Loss 0.7245
# Epoch 19 Batch 1000 Loss 0.7193
# Epoch 19 Batch 1100 Loss 0.5361
# Epoch 19 Batch 1200 Loss 0.6628
# Epoch 19 Batch 1300 Loss 0.7497
# Epoch 19 Batch 1400 Loss 0.6703
# Epoch 19 Batch 1500 Loss 0.7501
# Epoch 19 Batch 1600 Loss 0.7539
# Epoch 19 Batch 1700 Loss 0.6358
# Epoch 19 Batch 1800 Loss 0.7053
# Epoch 19 Batch 1900 Loss 0.6795
# Epoch 19 Loss 0.6496
# Time taken for 1 epoch 613.3162450790405 sec
#
# Epoch 20 Batch 0 Loss 0.4813
# Epoch 20 Batch 100 Loss 0.3971
# Epoch 20 Batch 200 Loss 0.6724
# Epoch 20 Batch 300 Loss 0.5369
# Epoch 20 Batch 400 Loss 0.5642
# Epoch 20 Batch 500 Loss 0.6401
# Epoch 20 Batch 600 Loss 0.5173
# Epoch 20 Batch 700 Loss 0.5856
# Epoch 20 Batch 800 Loss 0.5397
# Epoch 20 Batch 900 Loss 0.7304
# Epoch 20 Batch 1000 Loss 0.6183
# Epoch 20 Batch 1100 Loss 0.6284
# Epoch 20 Batch 1200 Loss 0.6264
# Epoch 20 Batch 1300 Loss 0.5889
# Epoch 20 Batch 1400 Loss 0.5388
# Epoch 20 Batch 1500 Loss 0.6206
# Epoch 20 Batch 1600 Loss 0.6602
# Epoch 20 Batch 1700 Loss 0.6071
# Epoch 20 Batch 1800 Loss 0.5841
# Epoch 20 Batch 1900 Loss 0.7181
# Epoch 20 Loss 0.6037
# Time taken for 1 epoch 614.8656594753265 sec
#
# Epoch 21 Batch 0 Loss 0.5458
# Epoch 21 Batch 100 Loss 0.6008
# Epoch 21 Batch 200 Loss 0.5322
# Epoch 21 Batch 300 Loss 0.6184
# Epoch 21 Batch 400 Loss 0.5297
# Epoch 21 Batch 500 Loss 0.4514
# Epoch 21 Batch 600 Loss 0.6074
# Epoch 21 Batch 700 Loss 0.4226
# Epoch 21 Batch 800 Loss 0.5238
# Epoch 21 Batch 900 Loss 0.5220
# Epoch 21 Batch 1000 Loss 0.4899
# Epoch 21 Batch 1100 Loss 0.4574
# Epoch 21 Batch 1200 Loss 0.4977
# Epoch 21 Batch 1300 Loss 0.5792
# Epoch 21 Batch 1400 Loss 0.5591
# Epoch 21 Batch 1500 Loss 0.5813
# Epoch 21 Batch 1600 Loss 0.6328
# Epoch 21 Batch 1700 Loss 0.7630
# Epoch 21 Batch 1800 Loss 0.5872
# Epoch 21 Batch 1900 Loss 0.6428
# Epoch 21 Loss 0.5616
# Time taken for 1 epoch 617.6410007476807 sec
#
# Epoch 22 Batch 0 Loss 0.5294
# Epoch 22 Batch 100 Loss 0.5467
# Epoch 22 Batch 200 Loss 0.7225
# Epoch 22 Batch 300 Loss 0.4694
# Epoch 22 Batch 400 Loss 0.5749
# Epoch 22 Batch 500 Loss 0.5251
# Epoch 22 Batch 600 Loss 0.4949
# Epoch 22 Batch 700 Loss 0.5489
# Epoch 22 Batch 800 Loss 0.5574
# Epoch 22 Batch 900 Loss 0.5051
# Epoch 22 Batch 1000 Loss 0.5128
# Epoch 22 Batch 1100 Loss 0.6983
# Epoch 22 Batch 1200 Loss 0.5633
# Epoch 22 Batch 1300 Loss 0.4723
# Epoch 22 Batch 1400 Loss 0.6232
# Epoch 22 Batch 1500 Loss 0.5393
# Epoch 22 Batch 1600 Loss 0.4866
# Epoch 22 Batch 1700 Loss 0.4568
# Epoch 22 Batch 1800 Loss 0.5860
# Epoch 22 Batch 1900 Loss 0.4118
# Epoch 22 Loss 0.5231
# Time taken for 1 epoch 616.6333844661713 sec
#
# Epoch 23 Batch 0 Loss 0.4305
# Epoch 23 Batch 100 Loss 0.5165
# Epoch 23 Batch 200 Loss 0.4743
# Epoch 23 Batch 300 Loss 0.4656
# Epoch 23 Batch 400 Loss 0.4895
# Epoch 23 Batch 500 Loss 0.3738
# Epoch 23 Batch 600 Loss 0.5104
# Epoch 23 Batch 700 Loss 0.5242
# Epoch 23 Batch 800 Loss 0.5324
# Epoch 23 Batch 900 Loss 0.4370
# Epoch 23 Batch 1000 Loss 0.5787
# Epoch 23 Batch 1100 Loss 0.5986
# Epoch 23 Batch 1200 Loss 0.4788
# Epoch 23 Batch 1300 Loss 0.5506
# Epoch 23 Batch 1400 Loss 0.6225
# Epoch 23 Batch 1500 Loss 0.5693
# Epoch 23 Batch 1600 Loss 0.5730
# Epoch 23 Batch 1700 Loss 0.4239
# Epoch 23 Batch 1800 Loss 0.4293
# Epoch 23 Batch 1900 Loss 0.5344
# Epoch 23 Loss 0.4869
# Time taken for 1 epoch 613.0306353569031 sec
#
# Epoch 24 Batch 0 Loss 0.3972
# Epoch 24 Batch 100 Loss 0.3470
# Epoch 24 Batch 200 Loss 0.4038
# Epoch 24 Batch 300 Loss 0.4248
# Epoch 24 Batch 400 Loss 0.3119
# Epoch 24 Batch 500 Loss 0.4736
# Epoch 24 Batch 600 Loss 0.4038
# Epoch 24 Batch 700 Loss 0.5238
# Epoch 24 Batch 800 Loss 0.4690
# Epoch 24 Batch 900 Loss 0.4161
# Epoch 24 Batch 1000 Loss 0.4201
# Epoch 24 Batch 1100 Loss 0.5042
# Epoch 24 Batch 1200 Loss 0.5493
# Epoch 24 Batch 1300 Loss 0.5354
# Epoch 24 Batch 1400 Loss 0.3530
# Epoch 24 Batch 1500 Loss 0.4503
# Epoch 24 Batch 1600 Loss 0.5788
# Epoch 24 Batch 1700 Loss 0.5487
# Epoch 24 Batch 1800 Loss 0.4294
# Epoch 24 Batch 1900 Loss 0.5441
# Epoch 24 Loss 0.4538
# Time taken for 1 epoch 616.5075840950012 sec
#
# Epoch 25 Batch 0 Loss 0.3794
# Epoch 25 Batch 100 Loss 0.3140
# Epoch 25 Batch 200 Loss 0.2739
# Epoch 25 Batch 300 Loss 0.4048
# Epoch 25 Batch 400 Loss 0.4092
# Epoch 25 Batch 500 Loss 0.4508
# Epoch 25 Batch 600 Loss 0.4197
# Epoch 25 Batch 700 Loss 0.3901
# Epoch 25 Batch 800 Loss 0.4358
# Epoch 25 Batch 900 Loss 0.4151
# Epoch 25 Batch 1000 Loss 0.4163
# Epoch 25 Batch 1100 Loss 0.3530
# Epoch 25 Batch 1200 Loss 0.4784
# Epoch 25 Batch 1300 Loss 0.4374
# Epoch 25 Batch 1400 Loss 0.4661
# Epoch 25 Batch 1500 Loss 0.4458
# Epoch 25 Batch 1600 Loss 0.4544
# Epoch 25 Batch 1700 Loss 0.4385
# Epoch 25 Batch 1800 Loss 0.3998
# Epoch 25 Batch 1900 Loss 0.5003
# Epoch 25 Loss 0.4237
# Time taken for 1 epoch 618.5713312625885 sec
#
# Epoch 26 Batch 0 Loss 0.3529
# Epoch 26 Batch 100 Loss 0.3424
# Epoch 26 Batch 200 Loss 0.3604
# Epoch 26 Batch 300 Loss 0.4514
# Epoch 26 Batch 400 Loss 0.3721
# Epoch 26 Batch 500 Loss 0.3113
# Epoch 26 Batch 600 Loss 0.3135
# Epoch 26 Batch 700 Loss 0.3901
# Epoch 26 Batch 800 Loss 0.2919
# Epoch 26 Batch 900 Loss 0.4209
# Epoch 26 Batch 1000 Loss 0.4532
# Epoch 26 Batch 1100 Loss 0.3426
# Epoch 26 Batch 1200 Loss 0.4331
# Epoch 26 Batch 1300 Loss 0.3661
# Epoch 26 Batch 1400 Loss 0.3786
# Epoch 26 Batch 1500 Loss 0.3336
# Epoch 26 Batch 1600 Loss 0.3625
# Epoch 26 Batch 1700 Loss 0.4080
# Epoch 26 Batch 1800 Loss 0.4641
# Epoch 26 Batch 1900 Loss 0.3805
# Epoch 26 Loss 0.3962
# Time taken for 1 epoch 616.8750562667847 sec
#
# Epoch 27 Batch 0 Loss 0.3432
# Epoch 27 Batch 100 Loss 0.3405
# Epoch 27 Batch 200 Loss 0.2923
# Epoch 27 Batch 300 Loss 0.3320
# Epoch 27 Batch 400 Loss 0.3202
# Epoch 27 Batch 500 Loss 0.3089
# Epoch 27 Batch 600 Loss 0.4128
# Epoch 27 Batch 700 Loss 0.3844
# Epoch 27 Batch 800 Loss 0.4663
# Epoch 27 Batch 900 Loss 0.3989
# Epoch 27 Batch 1000 Loss 0.3623
# Epoch 27 Batch 1100 Loss 0.3758
# Epoch 27 Batch 1200 Loss 0.3547
# Epoch 27 Batch 1300 Loss 0.4747
# Epoch 27 Batch 1400 Loss 0.3759
# Epoch 27 Batch 1500 Loss 0.3615
# Epoch 27 Batch 1600 Loss 0.3975
# Epoch 27 Batch 1700 Loss 0.3419
# Epoch 27 Batch 1800 Loss 0.4546
# Epoch 27 Batch 1900 Loss 0.3508
# Epoch 27 Loss 0.3702
# Time taken for 1 epoch 615.1505959033966 sec
#
# Epoch 28 Batch 0 Loss 0.2953
# Epoch 28 Batch 100 Loss 0.2476
# Epoch 28 Batch 200 Loss 0.3892
# Epoch 28 Batch 300 Loss 0.2760
# Epoch 28 Batch 400 Loss 0.3316
# Epoch 28 Batch 500 Loss 0.2751
# Epoch 28 Batch 600 Loss 0.3105
# Epoch 28 Batch 700 Loss 0.2225
# Epoch 28 Batch 800 Loss 0.3530
# Epoch 28 Batch 900 Loss 0.3065
# Epoch 28 Batch 1000 Loss 0.3407
# Epoch 28 Batch 1100 Loss 0.3279
# Epoch 28 Batch 1200 Loss 0.3956
# Epoch 28 Batch 1300 Loss 0.2542
# Epoch 28 Batch 1400 Loss 0.4025
# Epoch 28 Batch 1500 Loss 0.3084
# Epoch 28 Batch 1600 Loss 0.4353
# Epoch 28 Batch 1700 Loss 0.3118
# Epoch 28 Batch 1800 Loss 0.3705
# Epoch 28 Batch 1900 Loss 0.4195
# Epoch 28 Loss 0.3469
# Time taken for 1 epoch 615.2801203727722 sec
#
# Epoch 29 Batch 0 Loss 0.2913
# Epoch 29 Batch 100 Loss 0.3509
# Epoch 29 Batch 200 Loss 0.2911
# Epoch 29 Batch 300 Loss 0.2890
# Epoch 29 Batch 400 Loss 0.2657
# Epoch 29 Batch 500 Loss 0.4018
# Epoch 29 Batch 600 Loss 0.3434
# Epoch 29 Batch 700 Loss 0.2807
# Epoch 29 Batch 800 Loss 0.3518
# Epoch 29 Batch 900 Loss 0.3153
# Epoch 29 Batch 1000 Loss 0.2732
# Epoch 29 Batch 1100 Loss 0.4200
# Epoch 29 Batch 1200 Loss 0.4550
# Epoch 29 Batch 1300 Loss 0.2893
# Epoch 29 Batch 1400 Loss 0.3768
# Epoch 29 Batch 1500 Loss 0.3575
# Epoch 29 Batch 1600 Loss 0.3806
# Epoch 29 Batch 1700 Loss 0.3364
# Epoch 29 Batch 1800 Loss 0.3483
# Epoch 29 Batch 1900 Loss 0.3990
# Epoch 29 Loss 0.3256
# Time taken for 1 epoch 614.1217224597931 sec
#
# Epoch 30 Batch 0 Loss 0.3046
# Epoch 30 Batch 100 Loss 0.2535
# Epoch 30 Batch 200 Loss 0.3286
# Epoch 30 Batch 300 Loss 0.2566
# Epoch 30 Batch 400 Loss 0.3189
# Epoch 30 Batch 500 Loss 0.3134
# Epoch 30 Batch 600 Loss 0.2175
# Epoch 30 Batch 700 Loss 0.2859
# Epoch 30 Batch 800 Loss 0.3431
# Epoch 30 Batch 900 Loss 0.2424
# Epoch 30 Batch 1000 Loss 0.3471
# Epoch 30 Batch 1100 Loss 0.2520
# Epoch 30 Batch 1200 Loss 0.3175
# Epoch 30 Batch 1300 Loss 0.2673
# Epoch 30 Batch 1400 Loss 0.2713
# Epoch 30 Batch 1500 Loss 0.2996
# Epoch 30 Batch 1600 Loss 0.4364
# Epoch 30 Batch 1700 Loss 0.3177
# Epoch 30 Batch 1800 Loss 0.3397
# Epoch 30 Batch 1900 Loss 0.3132
# Epoch 30 Loss 0.3064
# Time taken for 1 epoch 612.4328348636627 sec
#
# Epoch 31 Batch 0 Loss 0.2837
# Epoch 31 Batch 100 Loss 0.2272
# Epoch 31 Batch 200 Loss 0.1997
# Epoch 31 Batch 300 Loss 0.2835
# Epoch 31 Batch 400 Loss 0.2798
# Epoch 31 Batch 500 Loss 0.2609
# Epoch 31 Batch 600 Loss 0.2399
# Epoch 31 Batch 700 Loss 0.2324
# Epoch 31 Batch 800 Loss 0.2766
# Epoch 31 Batch 900 Loss 0.3122
# Epoch 31 Batch 1000 Loss 0.2969
# Epoch 31 Batch 1100 Loss 0.2627
# Epoch 31 Batch 1200 Loss 0.3746
# Epoch 31 Batch 1300 Loss 0.3012
# Epoch 31 Batch 1400 Loss 0.4141
# Epoch 31 Batch 1500 Loss 0.3479
# Epoch 31 Batch 1600 Loss 0.3633
# Epoch 31 Batch 1700 Loss 0.4075
# Epoch 31 Batch 1800 Loss 0.3794
# Epoch 31 Batch 1900 Loss 0.2175
# Epoch 31 Loss 0.2885
# Time taken for 1 epoch 615.0448071956635 sec
#
# Epoch 32 Batch 0 Loss 0.2345
# Epoch 32 Batch 100 Loss 0.2426
# Epoch 32 Batch 200 Loss 0.2204
# Epoch 32 Batch 300 Loss 0.2981
# Epoch 32 Batch 400 Loss 0.2727
# Epoch 32 Batch 500 Loss 0.2229
# Epoch 32 Batch 600 Loss 0.2260
# Epoch 32 Batch 700 Loss 0.2901
# Epoch 32 Batch 800 Loss 0.2528
# Epoch 32 Batch 900 Loss 0.2698
# Epoch 32 Batch 1000 Loss 0.2828
# Epoch 32 Batch 1100 Loss 0.2537
# Epoch 32 Batch 1200 Loss 0.2125
# Epoch 32 Batch 1300 Loss 0.3121
# Epoch 32 Batch 1400 Loss 0.2793
# Epoch 32 Batch 1500 Loss 0.2798
# Epoch 32 Batch 1600 Loss 0.2862
# Epoch 32 Batch 1700 Loss 0.2302
# Epoch 32 Batch 1800 Loss 0.3474
# Epoch 32 Batch 1900 Loss 0.3924
# Epoch 32 Loss 0.2721
# Time taken for 1 epoch 612.828572511673 sec
#
# Epoch 33 Batch 0 Loss 0.2024
# Epoch 33 Batch 100 Loss 0.2953
# Epoch 33 Batch 200 Loss 0.1249
# Epoch 33 Batch 300 Loss 0.2031
# Epoch 33 Batch 400 Loss 0.2805
# Epoch 33 Batch 500 Loss 0.2346
# Epoch 33 Batch 600 Loss 0.2420
# Epoch 33 Batch 700 Loss 0.2347
# Epoch 33 Batch 800 Loss 0.2447
# Epoch 33 Batch 900 Loss 0.2811
# Epoch 33 Batch 1000 Loss 0.2334
# Epoch 33 Batch 1100 Loss 0.2307
# Epoch 33 Batch 1200 Loss 0.2808
# Epoch 33 Batch 1300 Loss 0.2299
# Epoch 33 Batch 1400 Loss 0.3545
# Epoch 33 Batch 1500 Loss 0.2721
# Epoch 33 Batch 1600 Loss 0.1904
# Epoch 33 Batch 1700 Loss 0.2357
# Epoch 33 Batch 1800 Loss 0.2966
# Epoch 33 Batch 1900 Loss 0.3540
# Epoch 33 Loss 0.2574
# Time taken for 1 epoch 615.6862483024597 sec
#
# Epoch 34 Batch 0 Loss 0.2368
# Epoch 34 Batch 100 Loss 0.1555
# Epoch 34 Batch 200 Loss 0.2413
# Epoch 34 Batch 300 Loss 0.2143
# Epoch 34 Batch 400 Loss 0.1975
# Epoch 34 Batch 500 Loss 0.2104
# Epoch 34 Batch 600 Loss 0.1687
# Epoch 34 Batch 700 Loss 0.2348
# Epoch 34 Batch 800 Loss 0.2040
# Epoch 34 Batch 900 Loss 0.2963
# Epoch 34 Batch 1000 Loss 0.2524
# Epoch 34 Batch 1100 Loss 0.2787
# Epoch 34 Batch 1200 Loss 0.2209
# Epoch 34 Batch 1300 Loss 0.2271
# Epoch 34 Batch 1400 Loss 0.3130
# Epoch 34 Batch 1500 Loss 0.2581
# Epoch 34 Batch 1600 Loss 0.2428
# Epoch 34 Batch 1700 Loss 0.2797
# Epoch 34 Batch 1800 Loss 0.2424
# Epoch 34 Batch 1900 Loss 0.2720
# Epoch 34 Loss 0.2446
# Time taken for 1 epoch 615.5375492572784 sec
#
# Epoch 35 Batch 0 Loss 0.2356
# Epoch 35 Batch 100 Loss 0.1807
# Epoch 35 Batch 200 Loss 0.1985
# Epoch 35 Batch 300 Loss 0.2483
# Epoch 35 Batch 400 Loss 0.1916
# Epoch 35 Batch 500 Loss 0.2903
# Epoch 35 Batch 600 Loss 0.1706
# Epoch 35 Batch 700 Loss 0.2158
# Epoch 35 Batch 800 Loss 0.2148
# Epoch 35 Batch 900 Loss 0.1976
# Epoch 35 Batch 1000 Loss 0.1678
# Epoch 35 Batch 1100 Loss 0.1440
# Epoch 35 Batch 1200 Loss 0.2685
# Epoch 35 Batch 1300 Loss 0.2594
# Epoch 35 Batch 1400 Loss 0.3479
# Epoch 35 Batch 1500 Loss 0.3131
# Epoch 35 Batch 1600 Loss 0.2538
# Epoch 35 Batch 1700 Loss 0.3118
# Epoch 35 Batch 1800 Loss 0.2796
# Epoch 35 Batch 1900 Loss 0.2183
# Epoch 35 Loss 0.2320
# Time taken for 1 epoch 615.6826400756836 sec
#
# Epoch 36 Batch 0 Loss 0.2022
# Epoch 36 Batch 100 Loss 0.2066
# Epoch 36 Batch 200 Loss 0.2276
# Epoch 36 Batch 300 Loss 0.1496
# Epoch 36 Batch 400 Loss 0.1881
# Epoch 36 Batch 500 Loss 0.1722
# Epoch 36 Batch 600 Loss 0.1887
# Epoch 36 Batch 700 Loss 0.2197
# Epoch 36 Batch 800 Loss 0.2160
# Epoch 36 Batch 900 Loss 0.1837
# Epoch 36 Batch 1000 Loss 0.2676
# Epoch 36 Batch 1100 Loss 0.2374
# Epoch 36 Batch 1200 Loss 0.2453
# Epoch 36 Batch 1300 Loss 0.2247
# Epoch 36 Batch 1400 Loss 0.2666
# Epoch 36 Batch 1500 Loss 0.2458
# Epoch 36 Batch 1600 Loss 0.2338
# Epoch 36 Batch 1700 Loss 0.2512
# Epoch 36 Batch 1800 Loss 0.2471
# Epoch 36 Batch 1900 Loss 0.2931
# Epoch 36 Loss 0.2219
# Time taken for 1 epoch 614.6444888114929 sec
#
# Epoch 37 Batch 0 Loss 0.2020
# Epoch 37 Batch 100 Loss 0.1895
# Epoch 37 Batch 200 Loss 0.2883
# Epoch 37 Batch 300 Loss 0.2062
# Epoch 37 Batch 400 Loss 0.1588
# Epoch 37 Batch 500 Loss 0.1786
# Epoch 37 Batch 600 Loss 0.2655
# Epoch 37 Batch 700 Loss 0.2627
# Epoch 37 Batch 800 Loss 0.2267
# Epoch 37 Batch 900 Loss 0.1638
# Epoch 37 Batch 1000 Loss 0.1816
# Epoch 37 Batch 1100 Loss 0.1733
# Epoch 37 Batch 1200 Loss 0.2417
# Epoch 37 Batch 1300 Loss 0.1939
# Epoch 37 Batch 1400 Loss 0.2384
# Epoch 37 Batch 1500 Loss 0.2319
# Epoch 37 Batch 1600 Loss 0.2033
# Epoch 37 Batch 1700 Loss 0.2429
# Epoch 37 Batch 1800 Loss 0.2119
# Epoch 37 Batch 1900 Loss 0.2025
# Epoch 37 Loss 0.2114
# Time taken for 1 epoch 613.204639673233 sec
#
# Epoch 38 Batch 0 Loss 0.2022
# Epoch 38 Batch 100 Loss 0.2334
# Epoch 38 Batch 200 Loss 0.1489
# Epoch 38 Batch 300 Loss 0.1716
# Epoch 38 Batch 400 Loss 0.1441
# Epoch 38 Batch 500 Loss 0.1769
# Epoch 38 Batch 600 Loss 0.1968
# Epoch 38 Batch 700 Loss 0.1787
# Epoch 38 Batch 800 Loss 0.1747
# Epoch 38 Batch 900 Loss 0.1806
# Epoch 38 Batch 1000 Loss 0.2067
# Epoch 38 Batch 1100 Loss 0.1893
# Epoch 38 Batch 1200 Loss 0.2750
# Epoch 38 Batch 1300 Loss 0.1999
# Epoch 38 Batch 1400 Loss 0.2357
# Epoch 38 Batch 1500 Loss 0.2219
# Epoch 38 Batch 1600 Loss 0.2193
# Epoch 38 Batch 1700 Loss 0.2485
# Epoch 38 Batch 1800 Loss 0.1651
# Epoch 38 Batch 1900 Loss 0.2689
# Epoch 38 Loss 0.2027
# Time taken for 1 epoch 613.5205233097076 sec
#
# Epoch 39 Batch 0 Loss 0.1476
# Epoch 39 Batch 100 Loss 0.1302
# Epoch 39 Batch 200 Loss 0.1735
# Epoch 39 Batch 300 Loss 0.1935
# Epoch 39 Batch 400 Loss 0.1459
# Epoch 39 Batch 500 Loss 0.1725
# Epoch 39 Batch 600 Loss 0.2145
# Epoch 39 Batch 700 Loss 0.1701
# Epoch 39 Batch 800 Loss 0.1686
# Epoch 39 Batch 900 Loss 0.1438
# Epoch 39 Batch 1000 Loss 0.1989
# Epoch 39 Batch 1100 Loss 0.2610
# Epoch 39 Batch 1200 Loss 0.2213
# Epoch 39 Batch 1300 Loss 0.1452
# Epoch 39 Batch 1400 Loss 0.1643
# Epoch 39 Batch 1500 Loss 0.2359
# Epoch 39 Batch 1600 Loss 0.2225
# Epoch 39 Batch 1700 Loss 0.1813
# Epoch 39 Batch 1800 Loss 0.2602
# Epoch 39 Batch 1900 Loss 0.2665
# Epoch 39 Loss 0.1938
# Time taken for 1 epoch 613.4075636863708 sec
#
# Epoch 40 Batch 0 Loss 0.1615
# Epoch 40 Batch 100 Loss 0.1416
# Epoch 40 Batch 200 Loss 0.1356
# Epoch 40 Batch 300 Loss 0.2010
# Epoch 40 Batch 400 Loss 0.1899
# Epoch 40 Batch 500 Loss 0.1658
# Epoch 40 Batch 600 Loss 0.1674
# Epoch 40 Batch 700 Loss 0.1854
# Epoch 40 Batch 800 Loss 0.2247
# Epoch 40 Batch 900 Loss 0.1942
# Epoch 40 Batch 1000 Loss 0.2266
# Epoch 40 Batch 1100 Loss 0.2442
# Epoch 40 Batch 1200 Loss 0.2555
# Epoch 40 Batch 1300 Loss 0.1770
# Epoch 40 Batch 1400 Loss 0.2440
# Epoch 40 Batch 1500 Loss 0.2513
# Epoch 40 Batch 1600 Loss 0.1272
# Epoch 40 Batch 1700 Loss 0.1585
# Epoch 40 Batch 1800 Loss 0.2199
# Epoch 40 Batch 1900 Loss 0.2156
# Epoch 40 Loss 0.1867
# Time taken for 1 epoch 613.7737636566162 sec
#
# Epoch 41 Batch 0 Loss 0.1391
# Epoch 41 Batch 100 Loss 0.1570
# Epoch 41 Batch 200 Loss 0.1233
# Epoch 41 Batch 300 Loss 0.1496
# Epoch 41 Batch 400 Loss 0.1844
# Epoch 41 Batch 500 Loss 0.1784
# Epoch 41 Batch 600 Loss 0.1406
# Epoch 41 Batch 700 Loss 0.2061
# Epoch 41 Batch 800 Loss 0.1992
# Epoch 41 Batch 900 Loss 0.1597
# Epoch 41 Batch 1000 Loss 0.1157
# Epoch 41 Batch 1100 Loss 0.1979
# Epoch 41 Batch 1200 Loss 0.1514
# Epoch 41 Batch 1300 Loss 0.1775
# Epoch 41 Batch 1400 Loss 0.2296
# Epoch 41 Batch 1500 Loss 0.1931
# Epoch 41 Batch 1600 Loss 0.1678
# Epoch 41 Batch 1700 Loss 0.1805
# Epoch 41 Batch 1800 Loss 0.2442
# Epoch 41 Batch 1900 Loss 0.1765
# Epoch 41 Loss 0.1808
# Time taken for 1 epoch 616.0594689846039 sec
#
# Epoch 42 Batch 0 Loss 0.1474
# Epoch 42 Batch 100 Loss 0.1183
# Epoch 42 Batch 200 Loss 0.1531
# Epoch 42 Batch 300 Loss 0.1580
# Epoch 42 Batch 400 Loss 0.2146
# Epoch 42 Batch 500 Loss 0.1660
# Epoch 42 Batch 600 Loss 0.1309
# Epoch 42 Batch 700 Loss 0.1843
# Epoch 42 Batch 800 Loss 0.1709
# Epoch 42 Batch 900 Loss 0.1819
# Epoch 42 Batch 1000 Loss 0.2545
# Epoch 42 Batch 1100 Loss 0.2061
# Epoch 42 Batch 1200 Loss 0.1568
# Epoch 42 Batch 1300 Loss 0.2276
# Epoch 42 Batch 1400 Loss 0.2614
# Epoch 42 Batch 1500 Loss 0.1831
# Epoch 42 Batch 1600 Loss 0.1832
# Epoch 42 Batch 1700 Loss 0.1706
# Epoch 42 Batch 1800 Loss 0.1663
# Epoch 42 Batch 1900 Loss 0.2587
# Epoch 42 Loss 0.1735
# Time taken for 1 epoch 613.7319386005402 sec
#
# Epoch 43 Batch 0 Loss 0.1116
# Epoch 43 Batch 100 Loss 0.1798
# Epoch 43 Batch 200 Loss 0.1335
# Epoch 43 Batch 300 Loss 0.1685
# Epoch 43 Batch 400 Loss 0.1074
# Epoch 43 Batch 500 Loss 0.1452
# Epoch 43 Batch 600 Loss 0.1803
# Epoch 43 Batch 700 Loss 0.2230
# Epoch 43 Batch 800 Loss 0.1628
# Epoch 43 Batch 900 Loss 0.1575
# Epoch 43 Batch 1000 Loss 0.1678
# Epoch 43 Batch 1100 Loss 0.1874
# Epoch 43 Batch 1200 Loss 0.1940
# Epoch 43 Batch 1300 Loss 0.1961
# Epoch 43 Batch 1400 Loss 0.2033
# Epoch 43 Batch 1500 Loss 0.1435
# Epoch 43 Batch 1600 Loss 0.2061
# Epoch 43 Batch 1700 Loss 0.1714
# Epoch 43 Batch 1800 Loss 0.1689
# Epoch 43 Batch 1900 Loss 0.1577
# Epoch 43 Loss 0.1689
# Time taken for 1 epoch 613.6418855190277 sec
#
# Epoch 44 Batch 0 Loss 0.1111
# Epoch 44 Batch 100 Loss 0.0943
# Epoch 44 Batch 200 Loss 0.1387
# Epoch 44 Batch 300 Loss 0.1310
# Epoch 44 Batch 400 Loss 0.1626
# Epoch 44 Batch 500 Loss 0.1483
# Epoch 44 Batch 600 Loss 0.1454
# Epoch 44 Batch 700 Loss 0.1906
# Epoch 44 Batch 800 Loss 0.2022
# Epoch 44 Batch 900 Loss 0.1654
# Epoch 44 Batch 1000 Loss 0.2072
# Epoch 44 Batch 1100 Loss 0.1407
# Epoch 44 Batch 1200 Loss 0.1023
# Epoch 44 Batch 1300 Loss 0.1844
# Epoch 44 Batch 1400 Loss 0.1775
# Epoch 44 Batch 1500 Loss 0.2071
# Epoch 44 Batch 1600 Loss 0.1351
# Epoch 44 Batch 1700 Loss 0.1896
# Epoch 44 Batch 1800 Loss 0.1858
# Epoch 44 Batch 1900 Loss 0.1492
# Epoch 44 Loss 0.1635
# Time taken for 1 epoch 613.2158930301666 sec
#
# Epoch 45 Batch 0 Loss 0.1341
# Epoch 45 Batch 100 Loss 0.1539
# Epoch 45 Batch 200 Loss 0.1297
# Epoch 45 Batch 300 Loss 0.1471
# Epoch 45 Batch 400 Loss 0.1279
# Epoch 45 Batch 500 Loss 0.1763
# Epoch 45 Batch 600 Loss 0.1232
# Epoch 45 Batch 700 Loss 0.1523
# Epoch 45 Batch 800 Loss 0.1470
# Epoch 45 Batch 900 Loss 0.2129
# Epoch 45 Batch 1000 Loss 0.1551
# Epoch 45 Batch 1100 Loss 0.2145
# Epoch 45 Batch 1200 Loss 0.1887
# Epoch 45 Batch 1300 Loss 0.1461
# Epoch 45 Batch 1400 Loss 0.1717
# Epoch 45 Batch 1500 Loss 0.1671
# Epoch 45 Batch 1600 Loss 0.1360
# Epoch 45 Batch 1700 Loss 0.1749
# Epoch 45 Batch 1800 Loss 0.1639
# Epoch 45 Batch 1900 Loss 0.2754
# Epoch 45 Loss 0.1589
# Time taken for 1 epoch 613.9154984951019 sec
#
# Epoch 46 Batch 0 Loss 0.1037
# Epoch 46 Batch 100 Loss 0.1276
# Epoch 46 Batch 200 Loss 0.1199
# Epoch 46 Batch 300 Loss 0.1724
# Epoch 46 Batch 400 Loss 0.1421
# Epoch 46 Batch 500 Loss 0.1428
# Epoch 46 Batch 600 Loss 0.1271
# Epoch 46 Batch 700 Loss 0.1687
# Epoch 46 Batch 800 Loss 0.1177
# Epoch 46 Batch 900 Loss 0.1179
# Epoch 46 Batch 1000 Loss 0.1768
# Epoch 46 Batch 1100 Loss 0.1538
# Epoch 46 Batch 1200 Loss 0.1774
# Epoch 46 Batch 1300 Loss 0.1533
# Epoch 46 Batch 1400 Loss 0.1767
# Epoch 46 Batch 1500 Loss 0.1450
# Epoch 46 Batch 1600 Loss 0.1866
# Epoch 46 Batch 1700 Loss 0.1176
# Epoch 46 Batch 1800 Loss 0.1866
# Epoch 46 Batch 1900 Loss 0.1761
# Epoch 46 Loss 0.1546
# Time taken for 1 epoch 613.1149716377258 sec
#
# Epoch 47 Batch 0 Loss 0.1412
# Epoch 47 Batch 100 Loss 0.1668
# Epoch 47 Batch 200 Loss 0.1569
# Epoch 47 Batch 300 Loss 0.1149
# Epoch 47 Batch 400 Loss 0.1345
# Epoch 47 Batch 500 Loss 0.1361
# Epoch 47 Batch 600 Loss 0.1349
# Epoch 47 Batch 700 Loss 0.0766
# Epoch 47 Batch 800 Loss 0.1734
# Epoch 47 Batch 900 Loss 0.1753
# Epoch 47 Batch 1000 Loss 0.1340
# Epoch 47 Batch 1100 Loss 0.1875
# Epoch 47 Batch 1200 Loss 0.1477
# Epoch 47 Batch 1300 Loss 0.1433
# Epoch 47 Batch 1400 Loss 0.2037
# Epoch 47 Batch 1500 Loss 0.2066
# Epoch 47 Batch 1600 Loss 0.1409
# Epoch 47 Batch 1700 Loss 0.2083
# Epoch 47 Batch 1800 Loss 0.1958
# Epoch 47 Batch 1900 Loss 0.1743
# Epoch 47 Loss 0.1518
# Time taken for 1 epoch 613.5948526859283 sec
#
# Epoch 48 Batch 0 Loss 0.1286
# Epoch 48 Batch 100 Loss 0.1073
# Epoch 48 Batch 200 Loss 0.0926
# Epoch 48 Batch 300 Loss 0.0922
# Epoch 48 Batch 400 Loss 0.1233
# Epoch 48 Batch 500 Loss 0.1072
# Epoch 48 Batch 600 Loss 0.1635
# Epoch 48 Batch 700 Loss 0.1551
# Epoch 48 Batch 800 Loss 0.1251
# Epoch 48 Batch 900 Loss 0.1783
# Epoch 48 Batch 1000 Loss 0.1317
# Epoch 48 Batch 1100 Loss 0.1390
# Epoch 48 Batch 1200 Loss 0.1659
# Epoch 48 Batch 1300 Loss 0.1940
# Epoch 48 Batch 1400 Loss 0.1296
# Epoch 48 Batch 1500 Loss 0.1608
# Epoch 48 Batch 1600 Loss 0.1433
# Epoch 48 Batch 1700 Loss 0.1608
# Epoch 48 Batch 1800 Loss 0.1213
# Epoch 48 Batch 1900 Loss 0.1916
# Epoch 48 Loss 0.1477
# Time taken for 1 epoch 613.8163080215454 sec
#
# Epoch 49 Batch 0 Loss 0.0850
# Epoch 49 Batch 100 Loss 0.0979
# Epoch 49 Batch 200 Loss 0.1201
# Epoch 49 Batch 300 Loss 0.1329
# Epoch 49 Batch 400 Loss 0.1123
# Epoch 49 Batch 500 Loss 0.1212
# Epoch 49 Batch 600 Loss 0.1556
# Epoch 49 Batch 700 Loss 0.1415
# Epoch 49 Batch 800 Loss 0.1388
# Epoch 49 Batch 900 Loss 0.1313
# Epoch 49 Batch 1000 Loss 0.1111
# Epoch 49 Batch 1100 Loss 0.1986
# Epoch 49 Batch 1200 Loss 0.1213
# Epoch 49 Batch 1300 Loss 0.1314
# Epoch 49 Batch 1400 Loss 0.1795
# Epoch 49 Batch 1500 Loss 0.1676
# Epoch 49 Batch 1600 Loss 0.1496
# Epoch 49 Batch 1700 Loss 0.1700
# Epoch 49 Batch 1800 Loss 0.2126
# Epoch 49 Batch 1900 Loss 0.1609
# Epoch 49 Loss 0.1447
# Time taken for 1 epoch 613.2901895046234 sec
#
# Epoch 50 Batch 0 Loss 0.1088
# Epoch 50 Batch 100 Loss 0.1269
# Epoch 50 Batch 200 Loss 0.1473
# Epoch 50 Batch 300 Loss 0.1363
# Epoch 50 Batch 400 Loss 0.1565
# Epoch 50 Batch 500 Loss 0.1805
# Epoch 50 Batch 600 Loss 0.1547
# Epoch 50 Batch 700 Loss 0.1129
# Epoch 50 Batch 800 Loss 0.1056
# Epoch 50 Batch 900 Loss 0.0970
# Epoch 50 Batch 1000 Loss 0.1290
# Epoch 50 Batch 1100 Loss 0.1340
# Epoch 50 Batch 1200 Loss 0.1554
# Epoch 50 Batch 1300 Loss 0.2177
# Epoch 50 Batch 1400 Loss 0.1919
# Epoch 50 Batch 1500 Loss 0.1405
# Epoch 50 Batch 1600 Loss 0.0786
# Epoch 50 Batch 1700 Loss 0.1107
# Epoch 50 Batch 1800 Loss 0.1717
# Epoch 50 Batch 1900 Loss 0.1787
# Epoch 50 Loss 0.1415
# Time taken for 1 epoch 612.8642015457153 sec
#
# Epoch 51 Batch 0 Loss 0.1037
# Epoch 51 Batch 100 Loss 0.1533
# Epoch 51 Batch 200 Loss 0.1184
# Epoch 51 Batch 300 Loss 0.0978
# Epoch 51 Batch 400 Loss 0.1139
# Epoch 51 Batch 500 Loss 0.1395
# Epoch 51 Batch 600 Loss 0.1004
# Epoch 51 Batch 700 Loss 0.1317
# Epoch 51 Batch 800 Loss 0.1523
# Epoch 51 Batch 900 Loss 0.1138
# Epoch 51 Batch 1000 Loss 0.0919
# Epoch 51 Batch 1100 Loss 0.1478
# Epoch 51 Batch 1200 Loss 0.1500
# Epoch 51 Batch 1300 Loss 0.1528
# Epoch 51 Batch 1400 Loss 0.0975
# Epoch 51 Batch 1500 Loss 0.1426
# Epoch 51 Batch 1600 Loss 0.1547
# Epoch 51 Batch 1700 Loss 0.1833
# Epoch 51 Batch 1800 Loss 0.1671
# Epoch 51 Batch 1900 Loss 0.1502
# Epoch 51 Loss 0.1393
# Time taken for 1 epoch 614.4822607040405 sec
#
# Epoch 52 Batch 0 Loss 0.1532
# Epoch 52 Batch 100 Loss 0.0960
# Epoch 52 Batch 200 Loss 0.1059
# Epoch 52 Batch 300 Loss 0.1279
# Epoch 52 Batch 400 Loss 0.1765
# Epoch 52 Batch 500 Loss 0.1320
# Epoch 52 Batch 600 Loss 0.1304
# Epoch 52 Batch 700 Loss 0.1565
# Epoch 52 Batch 800 Loss 0.1362
# Epoch 52 Batch 900 Loss 0.1303
# Epoch 52 Batch 1000 Loss 0.1553
# Epoch 52 Batch 1100 Loss 0.1283
# Epoch 52 Batch 1200 Loss 0.1406
# Epoch 52 Batch 1300 Loss 0.1397
# Epoch 52 Batch 1400 Loss 0.1156
# Epoch 52 Batch 1500 Loss 0.1408
# Epoch 52 Batch 1600 Loss 0.2420
# Epoch 52 Batch 1700 Loss 0.1730
# Epoch 52 Batch 1800 Loss 0.1585
# Epoch 52 Batch 1900 Loss 0.2037
# Epoch 52 Loss 0.1366
# Time taken for 1 epoch 613.5231807231903 sec
#
# Epoch 53 Batch 0 Loss 0.1150
# Epoch 53 Batch 100 Loss 0.2402
# Epoch 53 Batch 200 Loss 0.0961
# Epoch 53 Batch 300 Loss 0.0976
# Epoch 53 Batch 400 Loss 0.0943
# Epoch 53 Batch 500 Loss 0.0969
# Epoch 53 Batch 600 Loss 0.1648
# Epoch 53 Batch 700 Loss 0.0960
# Epoch 53 Batch 800 Loss 0.1234
# Epoch 53 Batch 900 Loss 0.1215
# Epoch 53 Batch 1000 Loss 0.1363
# Epoch 53 Batch 1100 Loss 0.1289
# Epoch 53 Batch 1200 Loss 0.1626
# Epoch 53 Batch 1300 Loss 0.1302
# Epoch 53 Batch 1400 Loss 0.1677
# Epoch 53 Batch 1500 Loss 0.0936
# Epoch 53 Batch 1600 Loss 0.1638
# Epoch 53 Batch 1700 Loss 0.1554
# Epoch 53 Batch 1800 Loss 0.1295
# Epoch 53 Batch 1900 Loss 0.2120
# Epoch 53 Loss 0.1341
# Time taken for 1 epoch 613.5211894512177 sec
#
# Epoch 54 Batch 0 Loss 0.1025
# Epoch 54 Batch 100 Loss 0.1026
# Epoch 54 Batch 200 Loss 0.1033
# Epoch 54 Batch 300 Loss 0.0840
# Epoch 54 Batch 400 Loss 0.0889
# Epoch 54 Batch 500 Loss 0.1463
# Epoch 54 Batch 600 Loss 0.1260
# Epoch 54 Batch 700 Loss 0.1464
# Epoch 54 Batch 800 Loss 0.1071
# Epoch 54 Batch 900 Loss 0.1089
# Epoch 54 Batch 1000 Loss 0.1425
# Epoch 54 Batch 1100 Loss 0.1648
# Epoch 54 Batch 1200 Loss 0.2055
# Epoch 54 Batch 1300 Loss 0.1179
# Epoch 54 Batch 1400 Loss 0.1098
# Epoch 54 Batch 1500 Loss 0.1155
# Epoch 54 Batch 1600 Loss 0.1066
# Epoch 54 Batch 1700 Loss 0.1683
# Epoch 54 Batch 1800 Loss 0.1410
# Epoch 54 Batch 1900 Loss 0.1488
# Epoch 54 Loss 0.1323
# Time taken for 1 epoch 612.9161293506622 sec
#
# Epoch 55 Batch 0 Loss 0.0726
# Epoch 55 Batch 100 Loss 0.1025
# Epoch 55 Batch 200 Loss 0.0989
# Epoch 55 Batch 300 Loss 0.1046
# Epoch 55 Batch 400 Loss 0.1019
# Epoch 55 Batch 500 Loss 0.1250
# Epoch 55 Batch 600 Loss 0.1090
# Epoch 55 Batch 700 Loss 0.1202
# Epoch 55 Batch 800 Loss 0.1419
# Epoch 55 Batch 900 Loss 0.1042
# Epoch 55 Batch 1000 Loss 0.1477
# Epoch 55 Batch 1100 Loss 0.1441
# Epoch 55 Batch 1200 Loss 0.2154
# Epoch 55 Batch 1300 Loss 0.1439
# Epoch 55 Batch 1400 Loss 0.1632
# Epoch 55 Batch 1500 Loss 0.1148
# Epoch 55 Batch 1600 Loss 0.1292
# Epoch 55 Batch 1700 Loss 0.1477
# Epoch 55 Batch 1800 Loss 0.1244
# Epoch 55 Batch 1900 Loss 0.1755
# Epoch 55 Loss 0.1304
# Time taken for 1 epoch 613.4538774490356 sec
#
# Epoch 56 Batch 0 Loss 0.1255
# Epoch 56 Batch 100 Loss 0.0919
# Epoch 56 Batch 200 Loss 0.1563
# Epoch 56 Batch 300 Loss 0.1019
# Epoch 56 Batch 400 Loss 0.0855
# Epoch 56 Batch 500 Loss 0.1464
# Epoch 56 Batch 600 Loss 0.1455
# Epoch 56 Batch 700 Loss 0.1250
# Epoch 56 Batch 800 Loss 0.1488
# Epoch 56 Batch 900 Loss 0.1438
# Epoch 56 Batch 1000 Loss 0.1563
# Epoch 56 Batch 1100 Loss 0.1344
# Epoch 56 Batch 1200 Loss 0.1184
# Epoch 56 Batch 1300 Loss 0.1297
# Epoch 56 Batch 1400 Loss 0.1764
# Epoch 56 Batch 1500 Loss 0.1431
# Epoch 56 Batch 1600 Loss 0.0941
# Epoch 56 Batch 1700 Loss 0.1003
# Epoch 56 Batch 1800 Loss 0.1366
# Epoch 56 Batch 1900 Loss 0.1018
# Epoch 56 Loss 0.1296
# Time taken for 1 epoch 613.5343463420868 sec
#
# Epoch 57 Batch 0 Loss 0.0591
# Epoch 57 Batch 100 Loss 0.1037
# Epoch 57 Batch 200 Loss 0.1533
# Epoch 57 Batch 300 Loss 0.1132
# Epoch 57 Batch 400 Loss 0.1493
# Epoch 57 Batch 500 Loss 0.1174
# Epoch 57 Batch 600 Loss 0.1331
# Epoch 57 Batch 700 Loss 0.0963
# Epoch 57 Batch 800 Loss 0.1162
# Epoch 57 Batch 900 Loss 0.1377
# Epoch 57 Batch 1000 Loss 0.1080
# Epoch 57 Batch 1100 Loss 0.0964
# Epoch 57 Batch 1200 Loss 0.1437
# Epoch 57 Batch 1300 Loss 0.1723
# Epoch 57 Batch 1400 Loss 0.0612
# Epoch 57 Batch 1500 Loss 0.1221
# Epoch 57 Batch 1600 Loss 0.1471
# Epoch 57 Batch 1700 Loss 0.1463
# Epoch 57 Batch 1800 Loss 0.1307
# Epoch 57 Batch 1900 Loss 0.1052
# Epoch 57 Loss 0.1263
# Time taken for 1 epoch 613.8607432842255 sec
#
# Epoch 58 Batch 0 Loss 0.0760
# Epoch 58 Batch 100 Loss 0.0892
# Epoch 58 Batch 200 Loss 0.1117
# Epoch 58 Batch 300 Loss 0.1054
# Epoch 58 Batch 400 Loss 0.0890
# Epoch 58 Batch 500 Loss 0.1231
# Epoch 58 Batch 600 Loss 0.0715
# Epoch 58 Batch 700 Loss 0.0880
# Epoch 58 Batch 800 Loss 0.1394
# Epoch 58 Batch 900 Loss 0.1491
# Epoch 58 Batch 1000 Loss 0.1189
# Epoch 58 Batch 1100 Loss 0.1666
# Epoch 58 Batch 1200 Loss 0.1220
# Epoch 58 Batch 1300 Loss 0.1152
# Epoch 58 Batch 1400 Loss 0.1478
# Epoch 58 Batch 1500 Loss 0.1432
# Epoch 58 Batch 1600 Loss 0.1343
# Epoch 58 Batch 1700 Loss 0.1509
# Epoch 58 Batch 1800 Loss 0.0897
# Epoch 58 Batch 1900 Loss 0.1990
# Epoch 58 Loss 0.1261
# Time taken for 1 epoch 613.2392737865448 sec
#
# Epoch 59 Batch 0 Loss 0.1001
# Epoch 59 Batch 100 Loss 0.1174
# Epoch 59 Batch 200 Loss 0.1092
# Epoch 59 Batch 300 Loss 0.0929
# Epoch 59 Batch 400 Loss 0.1524
# Epoch 59 Batch 500 Loss 0.1371
# Epoch 59 Batch 600 Loss 0.1385
# Epoch 59 Batch 700 Loss 0.1290
# Epoch 59 Batch 800 Loss 0.1501
# Epoch 59 Batch 900 Loss 0.0994
# Epoch 59 Batch 1000 Loss 0.1153
# Epoch 59 Batch 1100 Loss 0.1564
# Epoch 59 Batch 1200 Loss 0.0582
# Epoch 59 Batch 1300 Loss 0.1260
# Epoch 59 Batch 1400 Loss 0.1298
# Epoch 59 Batch 1500 Loss 0.1359
# Epoch 59 Batch 1600 Loss 0.1141
# Epoch 59 Batch 1700 Loss 0.1167
# Epoch 59 Batch 1800 Loss 0.1389
# Epoch 59 Batch 1900 Loss 0.1221
# Epoch 59 Loss 0.1233
# Time taken for 1 epoch 613.4099955558777 sec
#
# Epoch 60 Batch 0 Loss 0.0867
# Epoch 60 Batch 100 Loss 0.1311
# Epoch 60 Batch 200 Loss 0.0989
# Epoch 60 Batch 300 Loss 0.1384
# Epoch 60 Batch 400 Loss 0.1018
# Epoch 60 Batch 500 Loss 0.0714
# Epoch 60 Batch 600 Loss 0.1505
# Epoch 60 Batch 700 Loss 0.1367
# Epoch 60 Batch 800 Loss 0.1380
# Epoch 60 Batch 900 Loss 0.1230
# Epoch 60 Batch 1000 Loss 0.1396
# Epoch 60 Batch 1100 Loss 0.1652
# Epoch 60 Batch 1200 Loss 0.1594
# Epoch 60 Batch 1300 Loss 0.1086
# Epoch 60 Batch 1400 Loss 0.1101
# Epoch 60 Batch 1500 Loss 0.1832
# Epoch 60 Batch 1600 Loss 0.1459
# Epoch 60 Batch 1700 Loss 0.1481
# Epoch 60 Batch 1800 Loss 0.1509
# Epoch 60 Batch 1900 Loss 0.1236
# Epoch 60 Loss 0.1223
# Time taken for 1 epoch 612.675630569458 sec
#
# Epoch 61 Batch 0 Loss 0.1248
# Epoch 61 Batch 100 Loss 0.0719
# Epoch 61 Batch 200 Loss 0.0887
# Epoch 61 Batch 300 Loss 0.0692
# Epoch 61 Batch 400 Loss 0.0936
# Epoch 61 Batch 500 Loss 0.1302
# Epoch 61 Batch 600 Loss 0.1223
# Epoch 61 Batch 700 Loss 0.1170
# Epoch 61 Batch 800 Loss 0.1413
# Epoch 61 Batch 900 Loss 0.1204
# Epoch 61 Batch 1000 Loss 0.1066
# Epoch 61 Batch 1100 Loss 0.1387
# Epoch 61 Batch 1200 Loss 0.1406
# Epoch 61 Batch 1300 Loss 0.0926
# Epoch 61 Batch 1400 Loss 0.1314
# Epoch 61 Batch 1500 Loss 0.1124
# Epoch 61 Batch 1600 Loss 0.1016
# Epoch 61 Batch 1700 Loss 0.1353
# Epoch 61 Batch 1800 Loss 0.0892
# Epoch 61 Batch 1900 Loss 0.1354
# Epoch 61 Loss 0.1204
# Time taken for 1 epoch 615.1400880813599 sec

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += targ_lang.index_word[predicted_id] + ' '

        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence, attention_plot

    # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention_plot

# %%
def translate(sentence):
    result, sentence, _ = evaluate(sentence)

    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))
    return result[:-7]
  #attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  #plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]
print(max_length_targ, max_length_inp)
# Out:
# 20 20

# %%
translate("What are you doing here?")
# Out:
# Input: <start> what are you doing here <end>
# Predicted translation: i have come to protect my investment thank you <end>
# 'i have come to protect my investment thank you'

# %%
translate("i do not get it")
# Out:
# Input: <start> i do not get it <end>
# Predicted translation: it is poison gas this is the antidote drink it <end>

# %%
translate("it just does not seem right")
# Out:
# Input: <start> it just does not seem right <end>
# Predicted translation: do not fuck that guy that is why i do not know what the fuck are you gonna get the

# %%
translate("guys can i talk to you")
# Out:
# Input: <start> guys can i talk to you <end>
# Predicted translation: huh <end>

# %%
questions = ['Hello!',
'How are you?',
'What’s your name?',
'When were you born?',
'Where are you from?',
'Are you a man or a woman?',
'Why are you here?',
'Okay bye!',
'See you later.',
'Happy birthday!',
'Have a nice day!',
'How old are you?',
'Would you like some tea?',
'What a nice day today!',
'How do you do?',
'Hey.',
'What’s up?',
'Good morning.',
'How are you doing?',
'Nice to meet you.',
'Thank you.',
'Where are you going?',
'Good luck!',
'Sounds good?',
'Talk to you later.',
'How can i help you?',
'I do not feel very well.',
'I miss you.',
'What are you going to do?',
'I do not understand.',
'Who is Bill clinton?',
'Is the sky blue or black?',
'Does a cat have a ear?',
'Can a cat fly?',
'How many legs does a cat have?',
'How many legs does a spider have?',
'What is the color of the sky?',
'What is the color of water?',
'How much is two plus two?',
'How much is ten add two?',
'What do you like to talk about?',
'What is your job?',
'Tell me something about you.',
'What do you think about coffee?\xa0',
'Do you like math?',
'Can you tell me a joke?',
'I really like the song. What do you think?',
'Do you like basketball?',
'What kind of music do you like best?',
'What’s your favorite sport?']

# %%
i = 0
answers = []
for q in questions:
    print(i)
    answers.append(translate(q))
    i = i + 1
# Out:
# 0
# Input: <start> hello <end>
# Predicted translation: hello chris this is knox overstress <end>
# 1
# Input: <start> how are you <end>
# Predicted translation: fine <end>
# 2
# Input: <start> what s your name <end>
# Predicted translation: call me what have you been the wrong man who is business to meet your service sir <end>
# 3
# Input: <start> when were you born <end>
# Predicted translation: that was another one <end>
# 4
# Input: <start> where are you from <end>
# Predicted translation: helsinki which is the capital of finland <end>
# 5
# Input: <start> are you a man or a woman <end>
# Predicted translation: all right what she is at the man mr case is at all this <end>
# 6
# Input: <start> why are you here <end>
# Predicted translation: shitbela that is with the gun <end>
# 7
# Input: <start> okay bye <end>
# Predicted translation: i will see you therebye <end>
# 8
# Input: <start> see you later <end>
# Predicted translation: anyway you are crazy <end>
# 9
# Input: <start> happy birthday <end>
# Predicted translation: what do you think i should be carrying a torch for you <end>
# 10
# Input: <start> have a nice day <end>
# Predicted translation: well if it is a bad dream i can <end>
# 11
# Input: <start> how old are you <end>
# Predicted translation: older <end>
# 12
# Input: <start> would you like some tea <end>
# Predicted translation: thanks for me <end>
# 13
# Input: <start> what a nice day today <end>
# Predicted translation: it is a dump in the house i love that is it <end>
# 14
# Input: <start> how do you do <end>
# Predicted translation: how do you do mrs ryani would heard you do know <end>
# 15
# Input: <start> hey <end>
# Predicted translation: what <end>
# 16
# Input: <start> what s up <end>
# Predicted translation: johana let s go <end>
# 17
# Input: <start> good morning <end>
# Predicted translation: you think this shit is funny ho <end>
# 18
# Input: <start> how are you doing <end>
# Predicted translation: better i was really angry <end>
# 19
# Input: <start> nice to meet you <end>
# Predicted translation: oh thank you i think we shall be great friends do not you <end>
# 20
# Input: <start> thank you <end>
# Predicted translation: i have to talk to you <end>
# 21
# Input: <start> where are you going <end>
# Predicted translation: i have to leave now <end>
# 22
# Input: <start> good luck <end>
# Predicted translation: why <end>
# 23
# Input: <start> sounds good <end>
# Predicted translation: it is going to be great <end>
# 24
# Input: <start> talk to you later <end>
# Predicted translation: yeah he was looking <end>
# 25
# Input: <start> how can i help you <end>
# Predicted translation: where would you like who bothers you now <end>
# 26
# Input: <start> i do not feel very well <end>
# Predicted translation: what are you going to do <end>
# 27
# Input: <start> i miss you <end>
# Predicted translation: why <end>
# 28
# Input: <start> what are you going to do <end>
# Predicted translation: i will show you <end>
# 29
# Input: <start> i do not understand <end>
# Predicted translation: i am a cook do you understand cook <end>
# 30
# Input: <start> who is bill clinton <end>
# Predicted translation: mostly while he is <end>
# 31
# Input: <start> is the sky blue or black <end>
# Predicted translation: the lack of the horse passenger <end>
# 32
# Input: <start> does a cat have a ear <end>
# Predicted translation: yeah <end>
# 33
# Input: <start> can a cat fly <end>
# Predicted translation: the girl has to do with it <end>
# 34
# Input: <start> how many legs does a cat have <end>
# Predicted translation: three i have got to have you got here <end>
# 35
# Input: <start> how many legs does a spider have <end>
# Predicted translation: it is from a long time <end>
# 36
# Input: <start> what is the color of the sky <end>
# Predicted translation: the past i assure youwatch in the house <end>
# 37
# Input: <start> what is the color of water <end>
# Predicted translation: the children are not on the fight <end>
# 38
# Input: <start> how much is two plus two <end>
# Predicted translation: we can dad <end>
# 39
# Input: <start> how much is ten add two <end>
# Predicted translation: three months mr three years <end>
# 40
# Input: <start> what do you like to talk about <end>
# Predicted translation: we are too old already <end>
# 41
# Input: <start> what is your job <end>
# Predicted translation: i do not know i do not know i do not know i do not know i do not know
# 42
# Input: <start> tell me something about you <end>
# Predicted translation: later <end>
# 43
# Input: <start> what do you think about coffee <end>
# Predicted translation: well it is too bad he is too late trumanthere s eyes <end>
# 44
# Input: <start> do you like math <end>
# Predicted translation: i said i liked jesus i love my husband <end>
# 45
# Input: <start> can you tell me a joke <end>
# Predicted translation: if i get a class and two have <end>
# 46
# Input: <start> i really like the song what do you think <end>
# Predicted translation: it is okay <end>
# 47
# Input: <start> do you like basketball <end>
# Predicted translation: the door is coming <end>
# 48
# Input: <start> what kind of music do you like best <end>
# Predicted translation: well we are <end>
# 49
# Input: <start> what s your favorite sport <end>
# Predicted translation: i do not know i went to keep it easy man i could not get pretty <end>

# %%
import pandas as pd
d = {'questions': questions, 'answers': answers}
df = pd.DataFrame(data=d)

# %%
df.to_csv("cornell_results.csv", index=False, header=False)
